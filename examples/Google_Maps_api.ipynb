# %% [markdown]
# # Google Map API

# %%
# !python --version
# Out:
# Python 3.6.1

# %%
import googlemaps
#ref websites:
#https://developers.google.com/maps/web-services/client-library?hl=zh-tw
#https://developers.google.com/places/web-service/place-id?hl=zh-tw

# %%
import requests
import json
#24.9683044,121.187757
#key:AIzaSyBcOc1F1TW7Aqc8E5G4Xyn6jhIvhd9E2OE
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=24.9683044,121.187757&radius=500&type=restaurant&key=AIzaSyBcOc1F1TW7Aqc8E5G4Xyn6jhIvhd9E2OE"
res = requests.get(url,  headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'})
res.json()
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 24.9670437, 'lng': 121.1906793},
#     'viewport': {'northeast': {'lat': 24.9683926802915,
#       'lng': 121.1920282802915},
#      'southwest': {'lat': 24.9656947197085, 'lng': 121.1893303197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a7692688e10ba7103821cf0c1034628a8a2976fc',
#    'name': 'Mos Burger',
#    'opening_hours': {'open_now': False, 'weekday_text': []},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100079582125785512107/photos">Karen Won</a>'],
#      'photo_reference': 'CmRaAAAA-dshzc935KX-MNX0rLQTQIsfM-g0_Rv6gCZMHssCjN-LrLXqVkajrnS_HCYkh9kXQoBWyd0WC15ezpOlAlG3h4PoURN3ILaRGUwfDl5tdHoLdPkYBpfSRsx9KNw5TPUlEhDJpKGlnzOI_l6aTyH8vlAgGhRwLJpZlYNya5SYIXWkWRDTEgXEaQ',
#      'width': 3412}],
#    'place_id': 'ChIJ40uQ7MEjaDQRX-8AsKE3A1o',
#    'rating': 4,
# ...
